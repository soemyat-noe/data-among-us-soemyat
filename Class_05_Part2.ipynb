# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'DOB_Complaints_Received_20241022.csv'

# %%
complaints = pd.read_csv(path)
# Out:
# C:\Users\Soe-Myat\AppData\Local\Temp\ipykernel_24672\3939107886.py:1: DtypeWarning: Columns (5,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv(path)

# %%
complaints = pd.read_csv(path)
# Out:
# C:\Users\Soe-Myat\AppData\Local\Temp\ipykernel_24672\3939107886.py:1: DtypeWarning: Columns (5,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv(path)

# %%
complaints_df = pd.read_csv(path)
# Out:
# C:\Users\Soe-Myat\AppData\Local\Temp\ipykernel_24672\2340683946.py:1: DtypeWarning: Columns (5,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints_df = pd.read_csv(path)

# %%
complaints.head()
# Out:
#    Complaint Number  Status Date Entered House Number    House Street  \
# 0           1000008  CLOSED   01/03/1989          101        1 AVENUE
# 1           1000009  CLOSED   01/03/1989          101        1 AVENUE
# 2           4000001  CLOSED   01/03/1989       255-17       IOWA ROAD
# 3           1000017  CLOSED   01/03/1989          179   WEST BROADWAY
# 4           1000022  CLOSED   01/03/1989          133  EAST 22 STREET
#
#   ZIP Code      BIN Community Board Special District Complaint Category  Unit  \
# 0    10003  1006289             103              NaN                  3  MAN.
# 1    10003  1006289             103              NaN                  1  MAN.
# 2    11362  4171655             411              NaN                 45  QNS.
# 3    10013  1001966             101              NaN                 31  MAN.
# 4    10010  1086544             106              NaN                 46  MAN.
#
#   Disposition Date Disposition Code Inspection Date  DOBRunDate
# ...

# %%
complaints.Status
# Out:
# 0          CLOSED
# 1          CLOSED
# 2          CLOSED
# 3          CLOSED
# 4          CLOSED
#             ...
# 2900477    CLOSED
# 2900478    CLOSED
# 2900479    CLOSED
# 2900480    CLOSED
# 2900481    CLOSED
# Name: Status, Length: 2900482, dtype: object

# %%
complaints.Status.value_counts()
# Out:
# Status
# CLOSED    2874315
# ACTIVE      26167
# Name: count, dtype: int64

# %%
# subsection of the DataFrame - only using active complaints , think of it like a filter
# List comprehensions are back. 
# Two dimensions - Two sets of brackets
active_complaints_df = complaints_df[[ complaint for complaint in complaints_df.Status == 'ACTIVE']]

# %%
active_complaints_df
# Out:
#          Complaint Number  Status Date Entered House Number  \
# 305840            4164903  ACTIVE   04/22/2003        37-06
# 314614            1110389  ACTIVE   07/31/2003         1313
# 314661            5040821  ACTIVE   09/06/2003          330
# 333897            4173348  ACTIVE   08/22/2003         2304
# 337375            3117206  ACTIVE   08/11/2003           45
# ...                   ...     ...          ...          ...
# 2900432           3965417  ACTIVE   06/19/2024         1165
# 2900434           4966349  ACTIVE   07/20/2024        60-28
# 2900435           3971680  ACTIVE   08/07/2024         1165
# 2900441           2400076  ACTIVE   09/06/2024          500
# 2900444           4972355  ACTIVE   09/16/2024        60-28
#
#                House Street ZIP Code      BIN Community Board  \
# 305840            82 STREET  11372.0  4545554           403.0
# 314614   ST NICHOLAS AVENUE  10033.0  1063555           112.0
# ...

# %%
display(active_complaints_df)
# Out:
#          Complaint Number  Status Date Entered House Number  \
# 305840            4164903  ACTIVE   04/22/2003        37-06
# 314614            1110389  ACTIVE   07/31/2003         1313
# 314661            5040821  ACTIVE   09/06/2003          330
# 333897            4173348  ACTIVE   08/22/2003         2304
# 337375            3117206  ACTIVE   08/11/2003           45
# ...                   ...     ...          ...          ...
# 2900432           3965417  ACTIVE   06/19/2024         1165
# 2900434           4966349  ACTIVE   07/20/2024        60-28
# 2900435           3971680  ACTIVE   08/07/2024         1165
# 2900441           2400076  ACTIVE   09/06/2024          500
# 2900444           4972355  ACTIVE   09/16/2024        60-28
#
#                House Street ZIP Code      BIN Community Board  \
# 305840            82 STREET  11372.0  4545554           403.0
# 314614   ST NICHOLAS AVENUE  10033.0  1063555           112.0
# ...

# %%
active_complaints_df[100:120]
# Out:
#         Complaint Number  Status Date Entered House Number  \
# 840976           1139915  ACTIVE   04/09/2005          208
# 850592           1140080  ACTIVE   04/12/2005          210
# 853351           1123667  ACTIVE   06/03/2004          217
# 863250           1260937  ACTIVE   07/17/2009           37
# 863546           3313952  ACTIVE   07/31/2009           48
# 863664           3312421  ACTIVE   07/18/2009          722
# 863673           3314006  ACTIVE   07/31/2009           55
# 863675           3314004  ACTIVE   07/31/2009           53
# 863681           3314010  ACTIVE   07/31/2009          572
# 863682           3314011  ACTIVE   07/31/2009          572
# 863683           3314012  ACTIVE   07/31/2009          572
# 865077           3154881  ACTIVE   04/17/2005          986
# 866158           1140521  ACTIVE   04/19/2005            9
# 867678           1262366  ACTIVE   08/04/2009          700
# 869026           1124267  ACTIVE   06/14/2004           14
# ...

# %%
elev_accidents_df = complaints_df[[complaint for complaint in complaints_df['Complaint Category'] == '81']]

# %%
display(elev_accidents_df)
# Out:
#          Complaint Number  Status Date Entered House Number  \
# 393287            4116978  CLOSED   10/13/2000       136-50
# 393419            1092558  CLOSED   12/06/2001          151
# 394532            1106878  CLOSED   04/28/2003         2411
# 394679            1106850  CLOSED   04/28/2003          151
# 394748            1099845  CLOSED   08/19/2002           60
# ...                   ...     ...          ...          ...
# 2693654           1531300  CLOSED   12/20/2019          350
# 2724707           3924595  CLOSED   08/29/2023          460
# 2739329           1618416  CLOSED   09/19/2022          200
# 2780291           3935696  CLOSED   11/17/2023          114
# 2847574           1668776  CLOSED   05/24/2024          392
#
#               House Street ZIP Code      BIN Community Board Special District  \
# 393287    ROOSEVELT AVENUE    11354  4113551             407              NaN
# 393419    WEST   34 STREET    10001  1015219             105              NaN
# ...

# %%
#tolist () can convert a pandas list into a python list
street_names = elev_accidents_df['House Street'].tolist()
house_numbers =  elev_accidents_df['House Number'].tolist()
print(house_numbers)
# Out:
# ['136-50', '151', '2411', '151', '60', '10307', '136-50', '452', '212', '115', '200', '842', '529', '94', '65', '125', '151', '2895', '151', '2655', '3410', '246', '151', '1439', '271', '45', '5102', '151', '136-50', '441', '112', '303', '1401', '136-50', '136-50', '136-50', '216', '136-50', '39', '3041', '450', '441', '380', '1', '32', '10', '151', '3340', '441', '136-50', '124-21', '1745', '34-05', '868', '622', '274', '12421', '441', '1535', '139-05', '2190', '830', '830', '2307', '191', '77', '575', '4149', '575', '441', '161-10', '35', '1439', '1409', '136-50', '322', '1409', '441', '866', '151', '20', '2260', '2170', '1735', '451', '2655', '40', '286', '463', '151', '136-50', '332', '1815', '1555', '136-50', '530', '1998', '2950', '116', '151', '4', '151', '370', '2225', '441', '151', '781', '151', '135', '151', '395', '1830', '157', '53', '441', '1825', '136-50', '21', '200', '1889', '136-50', '430', '189', '441', '14', '1998', '151', '151', '36', '1420', '1420', '3250', '2187
# ...

# %%
list_a = [1,2,3]
list_b = [4,5,6]
print(list(zip(list_a, list_b)))

for x,y in list(zip(list_a, list_b)): 
    print (x)
    print (x*2)
# Out:
# [(1, 4), (2, 5), (3, 6)]
# 1
# 2
# 2
# 4
# 3
# 6

# %%
#Using list comprehension to merge two lists together
bad_places = [ num + "" + street for num, street in zip(house_numbers, street_names)]
print(bad_places)
# Out:
# ['136-50ROOSEVELT AVENUE', '151WEST   34 STREET', '24118 AVENUE', '151WEST   34 STREET', '60EAST   54 STREET', '10307FLATLANDS AVENUE', '136-50ROOSEVELT AVENUE', '4525 AVENUE', '212EAST   47 STREET', '115LOGAN STREET', '200WEST   58 STREET', '842UNION STREET', '529WEST   20 STREET', '94EAST    1 STREET', '65OCEAN AVENUE', '125EAST   72 STREET', '151WEST   34 STREET', '2895BEDFORD AVENUE', '151WEST   34 STREET', '2655RICHMOND AVENUE', '3410DEREIMER AVENUE', '246WEST   44 STREET', '151WEST   34 STREET', '1439METROPOLITAN AVENUE', '271CONVENT AVENUE', '45BROADWAY', '5102AVENUE U', '151WEST   34 STREET', '136-50ROOSEVELT AVENUE', '4417 AVENUE', '112CENTRAL PARK SOUTH', '303EAST   57 STREET', '1401METROPOLITAN AVENUE', '136-50ROOSEVELT AVENUE', '136-50ROOSEVELT AVENUE', '136-50ROOSEVELT AVENUE', '216ROCKAWAY AVENUE', '136-50ROOSEVELT AVENUE', '39BROADWAY', '3041BROADWAY', '450FLUSHING AVENUE', '4417 AVENUE', '380COZINE AVENUE', '1BEACH  105 STREET', '32BROADWAY', '10COLUMBUS CIRCLE', '151
# ...

# %%
from collections import Counter

# %%
worst_places = Counter(bad_places).most_common(5)
print(worst_places)
# Out:
# [('4417 AVENUE', 125), ('136-50ROOSEVELT AVENUE', 34), ('151WEST   34 STREET', 34), ('200PARK AVENUE', 22), ('90-15QUEENS BOULEVARD', 14)]
